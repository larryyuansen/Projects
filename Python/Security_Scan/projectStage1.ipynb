# %%
# """
# Comments:
# Notebook for used code in Stage 1:
# Part A:
#     aPart: initial as 0
#         0  : Error: not revieve Reply, should jump to Part F.
        
#         1  : Recieved ICMP reply.

# Part B: For ICMP
#     bPart: initial as -2 
#         -3 : Error: ICMP reply answers smaller than 3, cannot determine
#         -2 : Error: part A no anser, part B skiped
        
#         -1 : IP/ID counter type is: random.
#         0  : IP/ID counter type is: zero.
#         >0 : IP/ID counter type is: incremental.

# Part C:
#     cPart: initial as 0 
#         0  : Error: part A no answer or TCP not resonse, part C skiped
        
#         1  : Port 80 is open

# Part D: For TCP
#     dPart: initial as -2 
#         -3 : Error: TCP reply answers smaller than 3, cannot determine
#         -2 : Error: part A or C no answer, part D skiped
        
#         -1 : IP/ID counter type is: random.
#         0  : IP/ID counter type is: zero.
#         >0 : IP/ID counter type is: incremental.

# Part E:
#     ePart: initial as 0 
#         -1 : Error: no response on request
#         0  : Error: part A or C no response
        
#         1  : SYN cookies likely not deployed
#         2  : SYN cookies likely deployed

# Part F:
#     fPart: initial as 0
#         -1 : Error: cannot determine
#         0  : Error: device is not responsive (part A no response)
        
#         >0 : list combination below:
#             1  : Linux 2.4 and 2.6, Google customized Linux, Linux kernel 2.2, FreeBSD, OpenBSD, AIX 4.3 or MAC
#             2  : Windows 2000, XP, 7, Vista, and Server 8
#             3  : Sisco Router IOS 12.4, Solaris 7
#             4  : Google customized Linux
#             5  : Linux 2.4 and 2.6
#             6  : OpenBSD, AIX 4.3
#             7  : Linux kernel 2.2
#             8  : FreeBSD, MAC
#             9  : Windows 7, Vista and Server 8
#             10 : Windows 2000
#             11 : Windows XP
#             12 : Sisco Router IOS 12.4
#             13 : Solaris 7
# """

# %%
# import scapy
from scapy.all import *
import sys

# %%
# For cheking ID-IP counter type
def checkType(ans):
    idc = 0
    for i in range (len(ans)-1):
        dif = ans[i+1][1].id - ans[i][1].id
        if idc==0:
            idc=dif
        else:
            if idc==dif:
                continue
#             print(ans[i+1][1].id - ans[i][1].id)
            else:
                idc=-1
    return idc

# help method, for debug only, uesless for main code
def counterType(idc):
    if idc == 0:
        print("IP/ID counter type is: zero.")
    elif idc == -1:
        print("IP/ID counter type is: random.")
    elif idc > 0:   
        print("IP/ID counter type is: incremental.")
    else:
        print("Error")
    return

# For guesting likly OS of remote machine
def CheckOS(ttlR,winR):
    os=-1
    ttl = ttlR.ttl
    if winR is None:   
        if ttl<=64:
            os = 1
        elif ttl<=128:
            os = 2
        elif ttl<=255:
            os = 3
        else:
            os = -1
    else:
        windowSize = winR.window
        if ttl<=64:
            if windowSize<=5720:
                os=4
            elif windowSize<=5840:
                os=5
            elif windowSize<=16384:
                os=6
            elif windowSize<=32120:
                os=7
            elif windowSize<=65535:
                os=8
            else:
                os=-1 
        elif ttl<=128:
            if windowSize<=8192:
                os=9
            elif windowSize<=16384:
                os=10
            elif windowSize<=65535:
                os=11
            else:
                os=-1 
        elif ttl<=255:
            if windowSize<=4182:
                os=12
            elif windowSize<=8763:
                os=13
            else:
                os=-1 
        else:
            os = -1

    return os

# %%
# Stage 1 process
def stage1(ipAddress):
    ip = ipAddress
    print("")
    print(ip,":")
    ICMPr1 = None 
    ICMPr = None 
    ICMPur = None 
    TCPr1 = None 
    TCPr = None 
    TCPur = None 
    eTCPr = None 
    eTCPur = None 
#     Part A: Device is responsive:
    aPart = 0
    print("Part A:")
    ICMPr1 = sr1(IP(dst=ip)/ICMP(), timeout=5)
    if ICMPr1 is not None:
        aPart = 1 # part a got answer
#     else:
#         print("There is no response and request timeout for ICMP request")

#     Part B: IP-ID counter deployed by device (in ICMP pkts):
    bPart = -2
    if aPart==1:# if part a got answer
        print("Part B:")
        r = []
        rr = []   
        for i in range(5):
            r1 = sr1(IP(dst=ip)/ICMP(), timeout=5)
            if r1 is not None:
                rr.append((r,r1))
        if (len(rr)>2):
            bPart = checkType(rr)
        else:
            ICMPr,ICMPur = srloop(IP(dst=ip)/ICMP(),count=5)
            if len(ICMPr)>2:
                bPart = checkType(ICMPr)
            else:
                bPart = -3
#             print("Recieve packets less than 3, cannot determin the IP-ID couter type.")

#     Part C: Port 80 on device is open:
    cPart = 0
    if aPart==1:# if part a got answer
        print("Part C:")
        TCPr1 = sr1(IP(dst=ip)/TCP(flags='S',dport=80), timeout=5)
        if TCPr1 is not None:
            cPart = 1
#         else:
#             print("There is no response TCP ACK and request timeout for TCP SYN request")

#     Part D: IP-ID counter deployed by device (in TCP pkts):
    dPart = -2
    if (aPart==1 and cPart==1):# if part a, c got answer
        print("Part D:")
        r = []
        rr = []   
        for i in range(5):
            r1 = sr1(IP(dst=ip)/TCP(flags='S',dport=80), timeout=5)
            if r1 is not None:
                rr.append((r,r1))
        if (len(rr)>2):
            dPart = checkType(rr)
        else:
            TCPr,TCPur = srloop(IP(dst=ip)/TCP(flags='S',dport=80),count=5)
            if len(TCPr)>2:
                dPart = checkType(TCPr)
            else:
                dPart = -3
#             print("Recieve packets less than 3, cannot determin the IP-ID couter type.")

    # Part E: SYN cookies deployed by device:
    ePart = 0
    if (aPart==1 and cPart==1):# if part a, c got answer
        print("Part E:")
        # eTCPr,eTCPur = sr(IP(dst=ip)/TCP(flags='S',dport=80), timeout=0.5, multi =1)
        eTCPr,eTCPur = sr(IP(dst=ip)/TCP(flags='S',dport=80), timeout=60, multi =1)
        if eTCPr is None:
            ePart = -1
        elif len(eTCPr)==0:
            ePart = -1
        elif len(eTCPr)>1:
            ePart = 1
        elif len(eTCPr)==1:
            ePart = 2

    # Part F: Likely OS system deployed on the device:
    fPart = 0
    if aPart==1:
        print("Part F:")
        if cPart==1:
            fPart=CheckOS(ICMPr1,TCPr1)
            print()
        else:
            fPart=CheckOS(ICMPr1,None)

    # return aPart, bPart, cPart, dPart, ePart, fPart, ICMPr1, ICMPr, ICMPur, TCPr1, TCPr, TCPur, eTCPr
    return aPart, bPart, cPart, dPart, ePart, fPart

# %%
def evaluationPrint(ip,a,b,c,d,e,f):
    print("Evaluation output:")
    print(ip,":")
    print(" Part A:")
    if a==0:
        print("  Device is not responsive, reconnaissance terminated.")
    else:
        print("  Device is responsive.")
        print(" Part B:")
#         Part B
        if b==-3:
            print("  Error: ICMP reply answers smaller than 3")
        else:
            print("  IP-ID counter deployed by device (in ICMP pkts) is", end=' ')
            if b==-1:
                print("random.")
            elif b==0:
                print("zero.")
            elif b>0:
                print("incremental.")
        
        print(" Part C:")
        if c==0:
            print("  Port 80 on device is not open.")
        else:
            print("  Port 80 on device is open.")
            print(" Part D:")
            if d==-3:
                print("  Error: TCP reply answers smaller than 3.")
            else:
                print("  IP-ID counter deployed by device (in TCP pkts) is", end=' ')
                if d==-1:
                    print("random.")
                elif d==0:
                    print("zero.")
                elif d>0:
                    print("incremental.")
                    
            
            print(" Part E:")
            if e==-1:
                print("  Error: no response on request.")
            else:
                if e==1:
                    print("  SYN cookies not deployed.")
                elif e==2:
                    print("  SYN cookies likely deployed.")
        
        print(" Part F:")
        if f==-1:
            print("   Error: cannot determine.")
        else:
            print("  Likely OS system deployed on the device is: ", end=' ')
            if f==1:
                print("Linux 2.4 and 2.6, Google customized Linux, Linux kernel 2.2, FreeBSD, OpenBSD, AIX 4.3 or MAC.")
            elif f==2:
                print("Windows 2000, XP, 7, Vista, and Server 8.")
            elif f==3:
                print("Sisco Router IOS 12.4, Solaris 7.")
            elif f==4:
                print("Google customized Linux.")
            elif f==5:
                print("Linux 2.4 and 2.6.")
            elif f==6:
                print("OpenBSD, AIX 4.3.")
            elif f==7:
                print("Linux kernel 2.2.")
            elif f==8:
                print("FreeBSD or MAC.")
            elif f==9:
                print("Windows 7, Vista and Server 8.")
            elif f==10:
                print("Windows 2000.")
            elif f==11:
                print("Windows XP.")
            elif f==12:
                print("Sisco Router IOS 12.4.")
            elif f==13:
                print("Solaris 7.")
            else:
                print("Not Determin.")

# %%
# Main Process
# ip = input("Enter IP to scan: ")
# ip = "106.52.115.145"
# ip = "eecs.yorku.ca"
# ip = "8.8.8.8"
# ip = "www.virustotal.com"
# ip = "10.100.25.8"
# a,b,c,d,e,f,i1,i2,i3,t1,t2,t3,et = stage1(ip)


# ip = input("Enter IP to scan: ")
# ip = "106.52.115.145"
# a,b,c,d,e,f = stage1(ip)

# %%
# evaluationPrint(ip,a,b,c,d,e,f)

# %%
# Stage 2:
# read from input file
fileName = "Sony.txt"
file1 = open(fileName,"r+")
sonyIPs = file1.read().splitlines()
file1.close()

# Remove Duplicate IP address
sonyIPs = list(dict.fromkeys(sonyIPs))

sonyIPs.remove("IP")

print(len(sonyIPs))
# sonyIPs.sort()
# sonyIPs
# Out:
# 45

# %%
aa=[] 
bb=[]
cc=[]
dd=[]
ee=[]
ff=[]
count = 0 
for ips in sonyIPs:
    count+=1
    print("Percent: ",count, " / ", len(sonyIPs))
    # a1,b1,c1,d1,e1,f1,i11,i21,i31,t11,t21,t31,et1 = stage1(ips)
    a1,b1,c1,d1,e1,f1= stage1(ips)
    aa.append(a1)
    bb.append(b1)
    cc.append(c1)
    dd.append(d1)
    ee.append(e1)
    ff.append(f1)
# Out:
# Percent:  1  /  45
#
# 13.211.95.147 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 67 packets, got 0 answers, remaining 1 packets
# Percent:  2  /  45
#
# 15.185.134.185 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 16 packets, got 0 answers, remaining 1 packets
# Percent:  3  /  45
#
# 52.74.78.244 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 7 packets, got 0 answers, remaining 1 packets
# Percent:  4  /  45
#
# 106.52.115.145 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 195 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  5  /  45
#
# 199.247.11.85 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Part F:
# Percent:  6  /  45
#
# 45.32.28.50 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 494 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  7  /  45
#
# 42.194.226.30 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 250 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  8  /  45
#
# 42.194.230.121 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 29 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 386 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  9  /  45
#
# 101.36.105.97 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Percent:  10  /  45
#
# 123.207.23.211 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 21 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 131 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  11  /  45
#
# 165.22.204.232 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 401 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  12  /  45
#
# 134.73.55.10 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 81 packets, got 0 answers, remaining 1 packets
# Part F:
# Percent:  13  /  45
#
# 52.213.219.192 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 15 packets, got 0 answers, remaining 1 packets
# Percent:  14  /  45
#
# 221.182.247.65 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 7 packets, got 0 answers, remaining 1 packets
# Percent:  15  /  45
#
# 106.75.45.110 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 407 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  16  /  45
#
# 221.182.245.77 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 9 packets, got 0 answers, remaining 1 packets
# Percent:  17  /  45
#
# 106.75.71.81 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  18  /  45
#
# 117.48.120.226 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  19  /  45
#
# 117.50.22.73 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 1857 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  20  /  45
#
# 199.223.232.244 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 5 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3086 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  21  /  45
#
# 106.75.76.83 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 15 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 13 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 12 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 386 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 41 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 502 packets, got 0 answers, remaining 1 packets
# Part F:
# Percent:  22  /  45
#
# 221.182.245.85 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Percent:  23  /  45
#
# 221.182.144.37 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Percent:  24  /  45
#
# 221.182.136.129 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 15 packets, got 0 answers, remaining 1 packets
# Percent:  25  /  45
#
# 221.182.136.133 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 11 packets, got 0 answers, remaining 1 packets
# Percent:  26  /  45
#
# 221.176.82.65 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  27  /  45
#
# 221.176.82.73 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  28  /  45
#
# 221.182.254.17 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  29  /  45
#
# 221.182.245.225 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Percent:  30  /  45
#
# 221.182.144.17 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Percent:  31  /  45
#
# 221.182.247.177 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Percent:  32  /  45
#
# 106.75.91.237 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 9 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 4 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 57 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 374 packets, got 0 answers, remaining 1 packets
# Part F:
#
# Percent:  33  /  45
#
# 221.182.254.113 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 15 packets, got 0 answers, remaining 1 packets
# Percent:  34  /  45
#
# 221.176.82.81 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Percent:  35  /  45
#
# 13.209.159.235 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Percent:  36  /  45
#
# 221.176.88.201 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  37  /  45
#
# 117.50.11.67 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Percent:  38  /  45
#
# 155.138.134.102 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 8 packets, got 0 answers, remaining 1 packets
# Part F:
# Percent:  39  /  45
#
# 45.43.62.235 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 0 answers, remaining 1 packets
# Percent:  40  /  45
#
# 45.43.57.172 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 5 packets, got 0 answers, remaining 1 packets
# Percent:  41  /  45
#
# 111.230.206.141 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 5 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 55 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 311 packets, got 1 answers, remaining 0 packets
# Part F:
#
# Percent:  42  /  45
#
# 113.88.170.91 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 0 answers, remaining 1 packets
# Percent:  43  /  45
#
# 18.162.103.211 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 13 packets, got 0 answers, remaining 1 packets
# Percent:  44  /  45
#
# 113.88.168.224 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 18 packets, got 0 answers, remaining 1 packets
# Percent:  45  /  45
#
# 18.138.191.115 :
# Part A:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part B:
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 2 packets, got 1 answers, remaining 0 packets
# Part C:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Part D:
# Begin emission:
# Finished sending 1 packets.
#
# Received 3 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 14 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 6 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 20 packets, got 1 answers, remaining 0 packets
# Begin emission:
# Finished sending 1 packets.
#
# Received 10 packets, got 1 answers, remaining 0 packets
# Part E:
# Begin emission:
# Finished sending 1 packets.
#
# Received 167 packets, got 1 answers, remaining 0 packets
# Part F:

# %%
original_stdout = sys.stdout
f = open('Stage2out.txt', 'w')
sys.stdout = f # Change the standard output to the file we created.

for i in range (len(sonyIPs)):
    print()
    evaluationPrint(sonyIPs[i],aa[i],bb[i],cc[i],dd[i],ee[i],ff[i])

sys.stdout = original_stdout # Reset the standard output to its original value
f.close()

# %%
print("1. Name of IoT selected: Sony_IP_Camera")
print("2. Responsive devices:", aa.count(1), ",",(aa.count(1)/len(sonyIPs))*100,"%")
print("3.IP-ID in ICMP pkts (given devices with response):")
print(" Random:",bb.count(-1),",",(bb.count(-1)/aa.count(1))*100,"%,",end='')
print(" Zero:",bb.count(0),",",(bb.count(0)/aa.count(1))*100,"%,",end='')
print(" Incremental:",bb.count(1),",",(bb.count(1)/aa.count(1))*100,"%.")
print("4. Port 80 open:", cc.count(1), ",",(cc.count(1)/len(sonyIPs))*100,"%")
print("5. IP-ID in TCP pkts (given devices with port 80 open):")
print(" Random:",dd.count(-1),",",(dd.count(-1)/cc.count(1))*100,"%,",end='')
print(" Zero:",dd.count(0),",",(dd.count(0)/cc.count(1))*100,"%,",end='')
print(" Incremental:",dd.count(1),",",(dd.count(1)/cc.count(1))*100,"%.")
print("6. Devices that deploy SYN coockie(given devices with port 80 open): ",end='' )
print(ee.count(2), ",",(ee.count(2)/cc.count(1))*100,"%.")
windows=ff.count(1)+ff.count(5)+ff.count(7)
linux=ff.count(2)+ff.count(9)+ff.count(10)+ff.count(11)
print("7. Devices operation system(given devices with response):")
print(" Linux:",linux,",",linux/aa.count(1),"%,",end='')
print(" Windows:",windows,",",windows/aa.count(1)*100,"%.")
# Out:
# 1. Name of IoT selected: Sony_IP_Camera
# 2. Responsive devices: 16 , 35.55555555555556 %
# 3.IP-ID in ICMP pkts (given devices with response):
#  Random: 16 , 100.0 %, Zero: 0 , 0.0 %, Incremental: 0 , 0.0 %.
# 4. Port 80 open: 12 , 26.666666666666668 %
# 5. IP-ID in TCP pkts (given devices with port 80 open):
#  Random: 2 , 16.666666666666664 %, Zero: 10 , 83.33333333333334 %, Incremental: 0 , 0.0 %.
# 6. Devices that deploy SYN coockie(given devices with port 80 open): 11 , 91.66666666666666 %.
# 7. Devices operation system(given devices with response):
#  Linux: 0 , 0.0 %, Windows: 7 , 43.75 %.
